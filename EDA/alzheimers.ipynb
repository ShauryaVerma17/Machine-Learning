# %% [markdown]
# ### Libraries Needed

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Loading the Data

# %%
# Loading the data from CSV
data = pd.read_csv("../Datasets/alzheimers_disease_data.csv")

# %%
# Reading the shape of the dataset
data.shape
# Out:
# (2149, 35)

# %%
# See the data types of each column
data.dtypes
# Out:
# PatientID                      int64
# Age                            int64
# Gender                         int64
# Ethnicity                      int64
# EducationLevel                 int64
# BMI                          float64
# Smoking                        int64
# AlcoholConsumption           float64
# PhysicalActivity             float64
# DietQuality                  float64
# SleepQuality                 float64
# FamilyHistoryAlzheimers        int64
# CardiovascularDisease          int64
# Diabetes                       int64
# Depression                     int64
# HeadInjury                     int64
# Hypertension                   int64
# SystolicBP                     int64
# DiastolicBP                    int64
# CholesterolTotal             float64
# CholesterolLDL               float64
# CholesterolHDL               float64
# CholesterolTriglycerides     float64
# MMSE                         float64
# FunctionalAssessment         float64
# ...

# %%
# Preview the data
data.head(4)
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# 0                   0  1.725883          0               0
# 1                   0  2.592424          0               0
# ...

# %% [markdown]
# #### Checking for missing values

# %%
# See how many entries are null for each column
data.isnull().sum()
# Out:
# PatientID                    0
# Age                          0
# Gender                       0
# Ethnicity                    0
# EducationLevel               0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# ...

# %% [markdown]
# #### Understanding Statistical Summaries

# %%
# Describe the data for numerical features
data.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2149.000000  2149.000000  2149.000000  2149.000000     2149.000000
# mean   5825.000000    74.908795     0.506282     0.697534        1.286645
# std     620.507185     8.990221     0.500077     0.996128        0.904527
# min    4751.000000    60.000000     0.000000     0.000000        0.000000
# 25%    5288.000000    67.000000     0.000000     0.000000        1.000000
# 50%    5825.000000    75.000000     1.000000     0.000000        1.000000
# 75%    6362.000000    83.000000     1.000000     1.000000        2.000000
# max    6899.000000    90.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoking  AlcoholConsumption  PhysicalActivity  \
# count  2149.000000  2149.000000         2149.000000       2149.000000
# mean     27.655697     0.288506           10.039442          4.920202
# std       7.217438     0.453173            5.757910          2.857191
# ...

# %%
# Can check for specific columns as well
data.ADL.describe()
# Out:
# count    2149.000000
# mean        4.982958
# std         2.949775
# min         0.001288
# 25%         2.342836
# 50%         5.038973
# 75%         7.581490
# max         9.999747
# Name: ADL, dtype: float64

# %%
# Look at distribution values for categorical features
data.DoctorInCharge.value_counts()
# Out:
# DoctorInCharge
# XXXConfid    2149
# Name: count, dtype: int64

# %%
# Can be done for numerical features as well
data.EducationLevel.value_counts()
# Out:
# EducationLevel
# 1    854
# 2    636
# 0    446
# 3    213
# Name: count, dtype: int64

# %% [markdown]
# #### Visualizing the data

# %% [markdown]
# ##### Univariate Analysis
# Plots for looking at just one feature

# %%
data.Age.unique()
# Out:
# array([73, 89, 74, 86, 68, 75, 72, 87, 78, 84, 64, 69, 63, 65, 82, 77, 71,
#        83, 79, 67, 66, 70, 85, 60, 88, 62, 81, 61, 80, 90, 76])

# %%
# For Numerical Features
sns.histplot(data.Age)
plt.show()

sns.boxplot(data.Age)
plt.show()

# %%
# For categorical features
sns.countplot(data.DoctorInCharge)
plt.show()

# %% [markdown]
# ##### Bivariate Analysis
# 2 Features together

# %%
sns.scatterplot(x='Age', y='CholesterolTotal', data=data)
plt.show()

# %%
sns.scatterplot(x='CholesterolHDL', y='CholesterolLDL', data=data)
plt.show()

# %%
sns.scatterplot(x='CholesterolHDL', y='CholesterolTotal', data=data)
plt.show()

# %% [markdown]
# ##### Correlation Heatmap

# %%
data.drop('DoctorInCharge', axis=1, inplace=True)

# %%
corr_matrix = data.corr()
plt.figure(figsize=(40, 40))  # Adjust the size to fit your dataset
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.show()

# %% [markdown]
# #### Outlier Detection

# %%
# For numerical columns
sns.boxplot(data.Age)
plt.show()

# %%
sns.boxplot(data.CholesterolTotal)
plt.show()

# %% [markdown]
# ### Next Steps

# %% [markdown]
# #### Feature Engineering
# Create new features: Based on the existing ones, create new features if needed (e.g., extracting date parts, binning numerical data, encoding categorical variables).
#
# Transform features: Apply scaling or normalization if necessary (especially for algorithms sensitive to scale, like k-NN, SVMs, and neural networks).
#
# #### Check Class Imbalance (if applicable)
# If you're working with classification problems, check the distribution of target classes.
#
# If there's significant imbalance, consider strategies like:
#     Resampling (over-sampling the minority class or under-sampling the majority class)
#     Using class weights in models
#
# #### Feature Selection
# After visualizing and understanding the data, you may want to drop features that are irrelevant or highly correlated (multicollinearity).
#
# You can use statistical tests (e.g., chi-square test for categorical features) or algorithms like Recursive Feature Elimination (RFE) to select the most important features.
#
# #### Analyze and Interpret Results
# Based on the EDA, interpret the insights. What do you learn about the dataset’s structure, distribution, correlations, and outliers? Make sure to understand the context of the problem you are solving.
#
# #### Summarize Findings
# Prepare a summary of the findings from your EDA. This may include:
#
# Key observations on the data distribution
#
# Any data cleaning steps taken
#
# Decisions made about feature engineering and selection
#
# Insights about potential model performance or limitations
